# %% [markdown]
# # 01 — Preprocessing Tutorial
#
# Covers FR-01–FR-06: loading a multi-channel microscopy image, validating it,
# identifying mitochondrial/neuronal channels, normalizing intensity, and
# collapsing a Z-stack. These are the `mitomorph.preprocessing` modules with
# real (non-stub) implementations — this notebook runs end-to-end today.

# %%
from mitomorph.preprocessing.io import load_image
from mitomorph.preprocessing.validators import validate_image, validate_metadata
from mitomorph.preprocessing.channel_utils import extract_mitochondrial_channel, extract_neuronal_channel
from mitomorph.preprocessing.normalization import zscore_normalize, percentile_normalize
from mitomorph.preprocessing.zstack import max_intensity_projection

# image_path = "../data/raw/example.tif"
# image = load_image(image_path)
# validate_image(image)

# %% [markdown]
# ## Channel identification (FR-02, FR-15)

# %%
# mito_channel = extract_mitochondrial_channel(image)
# neuron_channel = extract_neuronal_channel(image)

# %% [markdown]
# ## Normalization and Z-stack projection (FR-04, FR-06)

# %%
# normalized = zscore_normalize(mito_channel)
# projected = max_intensity_projection(zstack_array)

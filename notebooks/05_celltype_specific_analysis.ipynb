# %% [markdown]
# # 05 — Cell-Type-Specific Analysis
#
# Covers FR-15–FR-18: separating neuronal from non-neuronal mitochondria,
# which is central to replicating Prof. Patel's neuron-specific respiratory
# capacity findings. Channel identification (`channel_utils`) is real;
# overlap-based classification (`celltype.classifier`) is a stub pending
# annotated images to tune the overlap threshold against.

# %%
from mitomorph.preprocessing.channel_utils import identify_channel_type, extract_neuronal_channel
from mitomorph.celltype.classifier import classify_neuronal

for name in ["Tom20-AF488", "NeuN", "DAPI"]:
    print(name, "->", identify_channel_type(name))

# %% [markdown]
# ## Neuronal vs. non-neuronal classification (FR-15–FR-17) — stub

# %%
# neuronal_labels = classify_neuronal(mito_mask, image)

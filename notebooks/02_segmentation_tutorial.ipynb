# %% [markdown]
# # 02 — Segmentation Tutorial
#
# Covers FR-08–FR-14: model architectures, inference, and validation metrics.
# `UNetResNet34`/`AttentionUNet` and `infer.segment()` are stubs pending a
# trained checkpoint; `segmentation.metrics` (Dice/IoU) is real and runnable
# today against any two masks.

# %%
from mitomorph.segmentation.models.unet import UNetResNet34
from mitomorph.segmentation.models.attention_unet import AttentionUNet
from mitomorph.segmentation.metrics import dice_score, iou_score

model = UNetResNet34()  # architecture stub; forward() not yet implemented

# %% [markdown]
# ## Validation metrics (FR-14, NFR-05) — real, runnable today

# %%
import numpy as np

pred_mask = np.zeros((64, 64), dtype=bool)
true_mask = np.zeros((64, 64), dtype=bool)
print("Dice:", dice_score(pred_mask, true_mask))
print("IoU:", iou_score(pred_mask, true_mask))

# %% [markdown]
# ## Inference (FR-12) — stub until a checkpoint exists

# %%
# from mitomorph.segmentation.infer import segment
# result = segment(model, preprocessed_image)

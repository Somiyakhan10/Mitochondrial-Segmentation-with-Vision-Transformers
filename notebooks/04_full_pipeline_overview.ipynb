# %% [markdown]
# # 04 — Full Pipeline Overview
#
# Demonstrates `MitoPipeline` (SRS §2.1): preprocessing -> segmentation ->
# cell-type classification -> morphometrics -> health classification ->
# reporting, wired in `mitomorph/pipeline.py`. Preprocessing, validation, and
# morphometric-stage wiring is real; running this today will get through those
# stages and then raise `NotImplementedError` at the segmentation stub — that's
# expected until a trained checkpoint exists (see `docs/api_reference.md`).

# %%
from mitomorph.pipeline import MitoPipeline

pipeline = MitoPipeline("../config/default_config.yaml")
metadata = {
    "animal_id": "M123",
    "experimental_condition": "SCI",
    "time_point": "6 weeks post-SCI",
}

# result = pipeline.run("../data/raw/example.tif", metadata)

# %% [markdown]
# ## Exporting results (FR-43) — real once `AnalysisResult` objects exist

# %%
# from mitomorph.reporting.export import to_csv, to_json
# to_json([result], "../data/processed/results.json")
# to_csv([result], "../data/processed/results.csv")
